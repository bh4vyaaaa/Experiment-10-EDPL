# %% [markdown]
# <a href="https://colab.research.google.com/github/bh4vyaaaa/Experiment-10-EDPL/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Experiment 10 : Create Dataset and Load Datasheet

# Name - Bhavya Pandya
# PRN - 25070123139
# Branch - F.Y. E&TC (2025-29)
# Batch - A1

# %%
import pandas as pd
data = {
    "Fruits" : ["Apple", "Banana", "Mango", "Grapes"],
    "Taste" : ["Sweet", "Sweet", "Sour", "Sour"],
    "Color" : ["Red", "Yellow", "Orange", "Green"],
    "Price" : [100, 60, 500, 140]
}
df = pd.DataFrame(data)
print(df)

df.to_csv("Fruits.csv",index=False)
df.to_excel("Fruits.xlsx",index=False)

Shape = df.shape
print("The Shape of the data is (Rows, Column) = ",Shape)

Info = df.info()
print(Info_Data)

First_Five_Rows = df.head()
Last_Five_Rows = df.tail()
# Out:
#    Fruits  Taste   Color  Price
# 0   Apple  Sweet     Red    100
# 1  Banana  Sweet  Yellow     60
# 2   Mango   Sour  Orange    500
# 3  Grapes   Sour   Green    140
# The Shape of the data is (Rows, Column) =  (4, 4)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Fruits  4 non-null      object
#  1   Taste   4 non-null      object
#  2   Color   4 non-null      object
#  3   Price   4 non-null      int64
# dtypes: int64(1), object(3)
# memory usage: 260.0+ bytes
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2075291127.py in <cell line: 0>()
#      16
#      17 Info = df.info()
# ---> 18 print(Info_Data)
#      19
#      20 First_Five_Rows = df.head()
#
# NameError: name 'Info_Data' is not defined

# %%
# Importing the Pandas
import pandas as pd

# Creating a dataset for us
data = {
    "Fruits" : ["Apple", "Banana", "Mango", "Grapes"],
    "Taste" : ["Sweet", "Sweet", "Sour", "Sour"],
    "Color" : ["Red", "Yellow", "Orange", "Green"],
    "Price" : [100, 60, 500, 140]
}
df = pd.DataFrame(data) # Making the dataframe form the dataset
print(df)

df.to_csv("Fruits.csv",index=False)
df.to_excel("Fruits.xlsx",index=False)

# Shape of the dataset
Shape = df.shape
print("The Shape of the data is (Rows, Column) = ",Shape)

# Getting more infomation about the dataset
Info = df.info()
print(Info_Data)

First_Five_Rows = df.head()
Last_Five_Rows = df.tail()
# Out:
#    Fruits  Taste   Color  Price
# 0   Apple  Sweet     Red    100
# 1  Banana  Sweet  Yellow     60
# 2   Mango   Sour  Orange    500
# 3  Grapes   Sour   Green    140
# The Shape of the data is (Rows, Column) =  (4, 4)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Fruits  4 non-null      object
#  1   Taste   4 non-null      object
#  2   Color   4 non-null      object
#  3   Price   4 non-null      int64
# dtypes: int64(1), object(3)
# memory usage: 260.0+ bytes
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4217646832.py in <cell line: 0>()
#      21 # Getting more infomation about the dataset
#      22 Info = df.info()
# ---> 23 print(Info_Data)
#      24
#      25 First_Five_Rows = df.head()
#
# NameError: name 'Info_Data' is not defined

# %%
Fruit_Names= df["Fruits"]
print(Fruit_Names)

# Solution 2:
Info_Grapes = df.loc[3]
print(Info_Grapes)

# Solution 3:
Data_Types = df.dtypes
print("The data types of each columns are : \n",Data_Types)

Info_Data = df.info()

# Adding new column
df["Quantity"] = [10, 20, 30, 40]

df.drop("Price",axis=1,inplace=False)

print(df)

# Solution 4:
Min_Price = df["Quantity"].min()
Max_Price = df["Quantity"].max()

print("Cheapest Fruit's Price : ",Min_Price)
print("Price Of Most Expensive Fruits: ",Max_Price)
# Out:
# 0     Apple
# 1    Banana
# 2     Mango
# 3    Grapes
# Name: Fruits, dtype: object
# Fruits    Grapes
# Taste       Sour
# Color      Green
# Price        140
# Name: 3, dtype: object
# The data types of each columns are :
#  Fruits    object
# Taste     object
# Color     object
# Price      int64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Fruits  4 non-null      object
#  1   Taste   4 non-null      object
#  2   Color   4 non-null      object
#  3   Price   4 non-null      int64
# dtypes: int64(1), object(3)
# memory usage: 260.0+ bytes
#    Fruits  Taste   Color  Price  Quantity
# 0   Apple  Sweet     Red    100        10
# 1  Banana  Sweet  Yellow     60        20
# 2   Mango   Sour  Orange    500        30
# 3  Grapes   Sour   Green    140        40
# Cheapest Fruit's Price :  10
# Price Of Most Expensive Fruits:  40

# %%
# Analysing The Given Dataset
import pandas as pd # Importing the Pandas Module
import numpy as np # Importing the NumPy Module
df = pd.read_csv("/content/Cars93.csv") # The data of file by giving it path

# For getting the size(No. of elements) in dataset
Size_Data = df.size
print("Total Number Of Elements : ",Size_Data)

# For getting the shape of the data set in format of (Rows,Columns)
Shape_Data = df.shape
print("The Shape of teh data (Rows,Columns) = ",Shape_Data)

# Getting more infomation about the dataset
Info_Data = df.info()
print(Info_Data)

# Getting first and last 5 rows of the given dataset
First_Five_Rows = df.head()
Last_Five_Rows = df.tail()

print("First five rows : \n",First_Five_Rows) # Printing first 5 rows
print("Columns five rows : \n",Last_Five_Rows) # Printing the last 5 rows
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2043869080.py in <cell line: 0>()
#       2 import pandas as pd # Importing the Pandas Module
#       3 import numpy as np # Importing the NumPy Module
# ----> 4 df = pd.read_csv("/content/Cars93.csv") # The data of file by giving it path
#       5
#       6 # For getting the size(No. of elements) in dataset
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/Cars93.csv'
